# %%
# ================================
# INSTALLS
# ================================

# !pip install pymupdf pillow pytesseract -q
# !apt-get install tesseract-ocr -q

# ================================
# IMPORTS
# ================================

import fitz
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pytesseract
import os
from google.colab import drive

drive.mount("/content/drive")

# ================================
# CONFIG
# ================================

PDF_DIR   = "/content/drive/MyDrive/glaze/swatches/1_1_pdfs"       # <-- folder containing all your PDFs
SAVE_BASE = "/content/drive/MyDrive/glaze/swatches/type_1_1_new"

VARIANCE_THRESHOLD = 21
MIN_SIZE = 1090
MAX_SIZE = 1200

GRID_ROWS = 4
GRID_COLS = 3

SWATCH_TOP    = 0.01
SWATCH_BOTTOM = 0.48
SWATCH_LEFT   = 0.54
SWATCH_RIGHT  = 1.0

TEXT_TOP    = 0.45
TEXT_BOTTOM = 0.60
TEXT_LEFT   = 0.65
TEXT_RIGHT  = 0.95

INSET = 8

SWATCH_MIN_SIZE = 110
SWATCH_MAX_SIZE = 125

# ================================
# HELPER FUNCTIONS
# ================================

def colour_variance(crop):
    return float(np.std(crop.astype(float)))


def overlap(a, b, threshold=0.5):
    ax, ay, aw, ah = a
    bx, by, bw, bh = b
    ix = max(0, min(ax+aw, bx+bw) - max(ax, bx))
    iy = max(0, min(ay+ah, by+bh) - max(ay, by))
    inter = ix * iy
    smaller = min(aw * ah, bw * bh)
    return inter / smaller > threshold if smaller > 0 else False


def detect_swatches(img_array):
    gray = cv2.cvtColor(img_array, cv2.COLOR_RGB2GRAY)
    blurred = cv2.GaussianBlur(gray, (3, 3), 0)
    edges = cv2.Canny(blurred, 30, 100)
    kernel = np.ones((3, 3), np.uint8)
    dilated = cv2.dilate(edges, kernel, iterations=2)
    contours, _ = cv2.findContours(dilated, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    accepted = []
    rejected = []

    for cnt in contours:
        x, y, w, h = cv2.boundingRect(cnt)
        if w < 20 or h < 20:
            continue

        crop = img_array[y:y+h, x:x+w]
        variance = colour_variance(crop)

        reasons = []
        if not (MIN_SIZE <= w <= MAX_SIZE and MIN_SIZE <= h <= MAX_SIZE):
            reasons.append(f"size {w}x{h}")
        if not (80 >= abs(w - h) >= 70):
            reasons.append(f"not square (diff={abs(w-h)})")
        if variance <= VARIANCE_THRESHOLD:
            reasons.append(f"flat var={variance:.0f}")

        if reasons:
            rejected.append((x, y, w, h, variance, ", ".join(reasons), crop))
        else:
            accepted.append((x, y, w, h, variance))

    filtered = []
    for c in sorted(accepted, key=lambda c: c[2]*c[3], reverse=True):
        if not any(overlap(c[:4], kept[:4]) for kept in filtered):
            filtered.append(c)

    return sorted(filtered, key=lambda c: (c[1], c[0])), rejected


def detect_swatches_in_cell(img_array):
    gray = cv2.cvtColor(img_array, cv2.COLOR_RGB2GRAY)
    blurred = cv2.GaussianBlur(gray, (3, 3), 0)
    edges = cv2.Canny(blurred, 30, 100)
    kernel = np.ones((3, 3), np.uint8)
    dilated = cv2.dilate(edges, kernel, iterations=2)
    contours, _ = cv2.findContours(dilated, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    accepted = []
    rejected = []

    for cnt in contours:
        x, y, w, h = cv2.boundingRect(cnt)
        if w < 20 or h < 20:
            continue

        crop = img_array[y:y+h, x:x+w]
        variance = colour_variance(crop)

        reasons = []
        if not (SWATCH_MIN_SIZE <= w <= SWATCH_MAX_SIZE and SWATCH_MIN_SIZE <= h <= SWATCH_MAX_SIZE):
            reasons.append(f"size {w}x{h}")
        if abs(w - h) > 10:
            reasons.append(f"not square (diff={abs(w-h)})")
        if variance <= VARIANCE_THRESHOLD:
            reasons.append(f"flat var={variance:.0f}")

        if reasons:
            rejected.append((x, y, w, h, variance, ", ".join(reasons), crop))
        else:
            accepted.append((x, y, w, h, variance))

    filtered = []
    for c in sorted(accepted, key=lambda c: c[2]*c[3], reverse=True):
        if not any(overlap(c[:4], kept[:4]) for kept in filtered):
            filtered.append(c)

    return sorted(filtered, key=lambda c: (c[1], c[0])), rejected


def clean_ocr(ocr_text, fallback):
    name = ocr_text.strip().replace(" ", "_").replace("/", "-").replace("\\", "-")
    name = "".join(c for c in name if c.isalnum() or c in "_-")
    return name if name else fallback


def unique_filename(save_dir, base_name):
    filename = f"{base_name}.png"
    counter = 1
    while os.path.exists(os.path.join(save_dir, filename)):
        filename = f"{base_name}_{counter}.png"
        counter += 1
    return filename

# ================================
# MAIN — PROCESS ALL PDFs
# ================================

pdf_files = [
    f for f in sorted(os.listdir(PDF_DIR))
    if f.lower().endswith(".pdf")
]

CONE_MAP = {
    1: "cone_6",
    2: "cone_10",
}

print(f"Found {len(pdf_files)} PDFs to process\n")

for pdf_name in pdf_files:
    pdf_path = os.path.join(PDF_DIR, pdf_name)
    original_filename = os.path.splitext(pdf_name)[0]

    print(f"\n{'='*60}")
    print(f"Processing: {pdf_name}")
    print(f"{'='*60}")

    doc = fitz.open(pdf_path)

    # ---- STAGE 1 + 2: DETECT GRIDS AND SPLIT INTO CELLS ----
    cells_by_page = {}

    for page_number, page in enumerate(doc, start=1):
        pix = page.get_pixmap(dpi=150)
        img_array = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, 3)

        accepted, _ = detect_swatches(img_array)
        print(f"  Page {page_number} — {len(accepted)} grid(s) found")

        cells_by_page[page_number] = []

        for grid_idx, (x, y, w, h, variance) in enumerate(accepted):
            grid_crop = img_array[y:y+h, x:x+w]
            gh, gw = grid_crop.shape[:2]

            cell_h = gh // GRID_ROWS
            cell_w = gw // GRID_COLS

            for row in range(GRID_ROWS):
                for col in range(GRID_COLS):
                    y1, y2 = row * cell_h, (row + 1) * cell_h
                    x1, x2 = col * cell_w, (col + 1) * cell_w
                    cell = grid_crop[y1:y2, x1:x2]
                    cell_num = row * GRID_COLS + col + 1
                    cells_by_page[page_number].append((grid_idx, cell_num, cell))

        print(f"    → {len(cells_by_page[page_number])} cells")

    # ---- STAGE 3: DETECT SWATCHES + OCR + SAVE ----
    for page_number, cells in cells_by_page.items():
        cone_folder = CONE_MAP.get(page_number, f"page_{page_number}")
        SAVE_DIR = os.path.join(SAVE_BASE, original_filename, cone_folder)
        os.makedirs(SAVE_DIR, exist_ok=True)

        print(f"\n  Page {page_number} → {cone_folder} ({len(cells)} cells)")

        total_swatches = 0
        total_saved    = 0

        for grid_idx, cell_num, cell in cells:
            cell_h, cell_w = cell.shape[:2]

            sy1 = int(cell_h * SWATCH_TOP)
            sy2 = int(cell_h * SWATCH_BOTTOM)
            sx1 = int(cell_w * SWATCH_LEFT)
            sx2 = int(cell_w * SWATCH_RIGHT)
            corner = cell[sy1:sy2, sx1:sx2]

            ty1 = int(cell_h * TEXT_TOP)
            ty2 = int(cell_h * TEXT_BOTTOM)
            tx1 = int(cell_w * TEXT_LEFT)
            tx2 = int(cell_w * TEXT_RIGHT)
            text_region = cell[ty1:ty2, tx1:tx2]

            ocr_text = pytesseract.image_to_string(
                Image.fromarray(text_region),
                config="--psm 6"
            ).strip()

            swatches, _ = detect_swatches_in_cell(corner)

            for idx, (x, y, w, h, variance) in enumerate(swatches):
                total_swatches += 1

                swatch = corner[y+INSET:y+h-INSET, x+INSET:x+w-INSET]

                fallback  = f"page{page_number:02d}_grid{grid_idx}_cell{cell_num:02d}_unknown"
                base_name = clean_ocr(ocr_text, fallback)
                filename  = unique_filename(SAVE_DIR, base_name)

                Image.fromarray(swatch).save(os.path.join(SAVE_DIR, filename))
                total_saved += 1
                print(f"      Saved: {filename}")

        print(f"    Swatches detected : {total_swatches}")
        print(f"    Files saved       : {total_saved}")
        print(f"    Files in folder   : {len(os.listdir(SAVE_DIR))}")

    doc.close()

print(f"\n{'='*60}")
print("All PDFs processed.")
# Out:
# Found 14 PDFs to process
#
#
# ============================================================
# Processing: SW-116-Robins-Egg.pdf
# ============================================================
#   Page 1 — 1 grid(s) found
#     → 12 cells
#   Page 2 — 1 grid(s) found
#     → 12 cells
#
#   Page 1 → cone_6 (12 cells)
#       Saved: EEEESW108_Green_Tea.png
#       Saved: SW148_Lime_Shower.png
#       Saved: EESW176_Sandstone.png
#       Saved: EEESW108_Green_Tea.png
#       Saved: SW148_Lime_Shower_1.png
#       Saved: SW176_Sandstone.png
#       Saved: W210_Emerald.png
#       Saved: W216_Micro_Jade.png
#       Saved: W255_Gray_Opal.png
#       Saved: W210_Emerald_1.png
#       Saved: SW216_Micro_Jade.png
#       Saved: W255_Gray_Opal_1.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
#   Page 2 → cone_10 (12 cells)
#       Saved: ESW108_Green_Tea.png
#       Saved: 7SW148_Lime_Shower.png
#       Saved: ESW176_Sandstone.png
#       Saved: EEESW108_Green_Tea.png
#       Saved: EESW148_Lime_Shower.png
#       Saved: ESW176_Sandstone_1.png
#       Saved: W210_Emerald.png
#       Saved: W216_Micro.png
#       Saved: 3255_Gray_Opal.png
#       Saved: SW210_Emerald.png
#       Saved: SW216_Micto_Cerulear.png
#       Saved: 3255_Gray_Opal_1.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
# ============================================================
# Processing: SW-122-Maycoshino.pdf
# ============================================================
#   Page 1 — 1 grid(s) found
#     → 12 cells
#   Page 2 — 1 grid(s) found
#     → 12 cells
#
#   Page 1 → cone_6 (12 cells)
#       Saved: W171_Enchanted_Fore.png
#       Saved: SW179_Muddy_Waters.png
#       Saved: SW180_Desert_Dusk.png
#       Saved: W171_Enchanted_Fore_1.png
#       Saved: SW179_Muddy_Waters_1.png
#       Saved: SW180_Desert_Dusk_1.png
#       Saved: SW218_Micro_Ash.png
#       Saved: W220_Black_Timber.png
#       Saved: W250_White_Opal.png
#       Saved: SW218_Micro_Ash_1.png
#       Saved: 5W220_Black_Timberi.png
#       Saved: SW250_White_Opal.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
#   Page 2 → cone_10 (12 cells)
#       Saved: EEW171_Enchanted_Fore.png
#       Saved: SW179_Muddy_Waters.png
#       Saved: SW180_Desert_Dusk.png
#       Saved: EEW171_Enchanted_Fore_1.png
#       Saved: SW179_Muddy_Waters_1.png
#       Saved: SW180_Desert_Dusk_1.png
#       Saved: SW218_Micro_Ash.png
#       Saved: W220_BlackTimber.png
#       Saved: W250_White_Opal.png
#       Saved: SW218_Micro_Ash_1.png
#       Saved: SW220_Black_Timber.png
#       Saved: 5250_White_Opal.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
# ============================================================
# Processing: SW-127-Olivine.pdf
# ============================================================
#   Page 1 — 1 grid(s) found
#     → 12 cells
#   Page 2 — 1 grid(s) found
#     → 12 cells
#
#   Page 1 → cone_6 (12 cells)
#       Saved: EEEE5W108_Green_Tea.png
#       Saved: SW146_Aurora_Green.png
#       Saved: SW148_Lime_Shower.png
#       Saved: EEEESW108_Green_Tea.png
#       Saved: SW146_Aurora_Green_1.png
#       Saved: SW148_Lime_Shower_1.png
#       Saved: W171_Enchanted_Fore.png
#       Saved: W181_Night_Moth.png
#       Saved: Swi92_Amarylis.png
#       Saved: W171_Enchanted_Fore_1.png
#       Saved: SW181_Night_Moth.png
#       Saved: SW192_Amarllis.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
#   Page 2 → cone_10 (12 cells)
#       Saved: EESW108_Green_Tea.png
#       Saved: SW146_Aurora_Green.png
#       Saved: 5W148_Lime_Shower.png
#       Saved: EEESW108_Green_Tea.png
#       Saved: SW146_Aurora_Green_1.png
#       Saved: 5W148_Lime_Shower_1.png
#       Saved: W171_Enchanted_Fore.png
#       Saved: W181_Night_Moth.png
#       Saved: Swi92_Amarylis.png
#       Saved: W171_Enchanted_Fore_1.png
#       Saved: W181_Night_Moth_1.png
#       Saved: Swi92_Amarylis_1.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
# ============================================================
# Processing: SW-147-Moonscape.pdf
# ============================================================
#   Page 1 — 1 grid(s) found
#     → 12 cells
#   Page 2 — 1 grid(s) found
#     → 12 cells
#
#   Page 1 → cone_6 (12 cells)
#       Saved: SW183_Oxblood.png
#       Saved: SW193_hy.png
#       Saved: EESW196_Sand_Dollar.png
#       Saved: SW183_Oxblood_1.png
#       Saved: EEW193_hy.png
#       Saved: SW196_Sand_Dollar.png
#       Saved: S197_Fossil_Rock.png
#       Saved: SW218_Micro_Ash.png
#       Saved: 5W253_Green_Opal.png
#       Saved: SW197_Fossil_Rock.png
#       Saved: SW218_Micro_Ash_1.png
#       Saved: SW253_Green_Opal.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
#   Page 2 → cone_10 (12 cells)
#       Saved: eeSW183_Oxblood.png
#       Saved: EEESW193_hy.png
#       Saved: E5W196_Sand_Dollar.png
#       Saved: ae5W183_Oxblood.png
#       Saved: W193_hy.png
#       Saved: ESW196_Sand_Dollar.png
#       Saved: S197_Fossil_Rock.png
#       Saved: SW218_Micro_Ash.png
#       Saved: 5253_Green_Opal.png
#       Saved: SW197_Fossil_Rock.png
#       Saved: SW218_Micro_Ash_1.png
#       Saved: 5253_Green_Opal_1.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
# ============================================================
# Processing: SW-201-Turquoise.pdf
# ============================================================
#   Page 1 — 1 grid(s) found
#     → 12 cells
#   Page 2 — 1 grid(s) found
#     → 12 cells
#
#   Page 1 → cone_6 (12 cells)
#       Saved: EESW118_Sea_Salt.png
#       Saved: SW121_Smoke.png
#       Saved: W196_Sand_Dollar.png
#       Saved: aSW118_Sea_Salt.png
#       Saved: SW121_Smoke_1.png
#       Saved: SW196_Sand_Dollar.png
#       Saved: SW198_Rose_Quartz.png
#       Saved: SW218_Micro_Ash.png
#       Saved: W219_Opal_Lustre.png
#       Saved: SW198_Rose_Quartz_1.png
#       Saved: SW218_Micro_Ash_1.png
#       Saved: SW219_Opal_Lustre.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
#   Page 2 → cone_10 (12 cells)
#       Saved: EEESW118_Sea_Salt.png
#       Saved: SW121_Smoke.png
#       Saved: W196_Sand_Dollar.png
#       Saved: EEESW118_Sea_Salt_1.png
#       Saved: SW121_Smoke_1.png
#       Saved: SW196_Sand_Dollar.png
#       Saved: SW198_Rose_Quartz.png
#       Saved: SW218_Micro_Ash.png
#       Saved: W219_Opal_Lustre.png
#       Saved: SW198_Rose_Quartz_1.png
#       Saved: SW218_Micro_Ash_1.png
#       Saved: W219_Opal_Lustre_1.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
# ============================================================
# Processing: SW-212-Peacock.pdf
# ============================================================
#   Page 1 — 1 grid(s) found
#     → 12 cells
#   Page 2 — 1 grid(s) found
#     → 12 cells
#
#   Page 1 → cone_6 (12 cells)
#       Saved: ESW118_Sea_Salt.png
#       Saved: W127_Olivine.png
#       Saved: SWI93_Ivy.png
#       Saved: SW118_Sea_Salt.png
#       Saved: W127_Olivine_1.png
#       Saved: SWig3_hy.png
#       Saved: SW214_Micro_Pearl.png
#       Saved: SW216_Micro_Jade.png
#       Saved: W219_Opal_Lustre.png
#       Saved: SW214_Micro_Pearl_1.png
#       Saved: SW216_Micro_Jade_1.png
#       Saved: SW219_Opal_Lustre.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
#   Page 2 → cone_10 (12 cells)
#       Saved: EEESW118_Sea_Salt.png
#       Saved: W127_Olivine.png
#       Saved: ESW193_Wy.png
#       Saved: EEESW118_Sea_Salt_1.png
#       Saved: W127_Olivine_1.png
#       Saved: EESW193_hy.png
#       Saved: SW214_Micro_Pearl.png
#       Saved: SW216_Micro_Jade.png
#       Saved: W219_Opal_Lustre.png
#       Saved: SW214_Micro_Pearl_1.png
#       Saved: W216_Micro_Jade.png
#       Saved: W219_Opal_Lustre_1.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
# ============================================================
# Processing: SW-219-Opal-Lustre.pdf
# ============================================================
#   Page 1 — 1 grid(s) found
#     → 12 cells
#   Page 2 — 1 grid(s) found
#     → 12 cells
#
#   Page 1 → cone_6 (12 cells)
#       Saved: SW101_Stoned_Denim.png
#       Saved: SWI_12Tiger_Eye.png
#       Saved: SW214_Micro_Pearl.png
#       Saved: SW101_Stoned_Denim_1.png
#       Saved: SW1T2_Tigers_Eye.png
#       Saved: SW214_Micro_Pearl_1.png
#       Saved: SW148_Lime_Shower.png
#       Saved: W199_Purple_Aster.png
#       Saved: 203_Root_Beer.png
#       Saved: SW148_Lime_Shower_1.png
#       Saved: SW199_Purple_Aster.png
#       Saved: SW203_Root_Beer.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
#   Page 2 → cone_10 (12 cells)
#       Saved: SW101_Stoned_Denim.png
#       Saved: SWI12_Tiger_Eye.png
#       Saved: SW214_Micto_Pearl.png
#       Saved: SW101_Stoned_Denim_1.png
#       Saved: SW112_Tigers_Eye.png
#       Saved: SW214_Micto_Pearl_1.png
#       Saved: SW148_Lime_Shower.png
#       Saved: SW199_Purple_Aster.png
#       Saved: 203_Root_Beer.png
#       Saved: SW148_Lime_Shower_1.png
#       Saved: SW199_Purple_Aster_1.png
#       Saved: 203_Root_Beer_1.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
# ============================================================
# Processing: SW-220-Black-Timber.pdf
# ============================================================
#   Page 1 — 1 grid(s) found
#     → 12 cells
#   Page 2 — 1 grid(s) found
#     → 12 cells
#
#   Page 1 → cone_6 (12 cells)
#       Saved: SW109_Capri_Blue.png
#       Saved: SW131_Birch.png
#       Saved: SW109_Capri_Blue_1.png
#       Saved: SW131_Birch_1.png
#       Saved: SW172_Macadamia.png
#       Saved: W177_Raspberry_Mist.png
#       Saved: W223_Milk_Glass.png
#       Saved: SW172_Macadamia_1.png
#       Saved: SW177_Raspberry_Mis.png
#       Saved: SW223_Milk_Glass.png
#     Swatches detected : 10
#     Files saved       : 10
#     Files in folder   : 10
#
#   Page 2 → cone_10 (12 cells)
#       Saved: EESW106_Alabaster.png
#       Saved: SW109_Capri_Blue.png
#       Saved: ee5W131_Birch.png
#       Saved: SW106_Alabaster.png
#       Saved: W103_Capri_Blue.png
#       Saved: SW131_Birch.png
#       Saved: SW172_Macadamia.png
#       Saved: W177_Raspberry_Mist.png
#       Saved: W223_Milk_Glass.png
#       Saved: SW172_Macadamial.png
#       Saved: SWI77_Raspberty_Mis.png
#       Saved: SW223_Milk_Glass.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
# ============================================================
# Processing: SW-221-Mint-Speck.pdf
# ============================================================
#   Page 1 — 1 grid(s) found
#     → 12 cells
#   Page 2 — 1 grid(s) found
#     → 12 cells
#
#   Page 1 → cone_6 (12 cells)
#       Saved: SW101_Stoned_Denim.png
#       Saved: SW130_Copper_Jade.png
#       Saved: SW131_Birch.png
#       Saved: SW101_Stoned_Denim_1.png
#       Saved: W130_Copper_Jade.png
#       Saved: SW131_Birch_1.png
#       Saved: SW193_yy.png
#       Saved: SW196_Sand_Dollar.png
#       Saved: W223_Milk_Glass.png
#       Saved: W198_Ivy.png
#       Saved: SW196_Sand_Dollar_1.png
#       Saved: SW223_Milk_Glass.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
#   Page 2 → cone_10 (12 cells)
#       Saved: SW101_Stoned_Denim.png
#       Saved: SW130_Copper_Jade.png
#       Saved: EE5W131_Birch.png
#       Saved: SW101_Stoned_Denim_1.png
#       Saved: W130_Copper_Jade.png
#       Saved: SW131_Birch.png
#       Saved: SW193_hy.png
#       Saved: SW196_Sand_Dollar.png
#       Saved: W223_Milk_Glass.png
#       Saved: W193_Ivy.png
#       Saved: SW196_Sand_Dollar_1.png
#       Saved: SW223_Milk_Glass.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
# ============================================================
# Processing: SW-222-Green-Jasper.pdf
# ============================================================
#   Page 1 — 1 grid(s) found
#     → 12 cells
#   Page 2 — 1 grid(s) found
#     → 12 cells
#
#   Page 1 → cone_6 (12 cells)
#       Saved: SW131_Birch.png
#       Saved: SW168_Coral_Sands.png
#       Saved: SW172_Macadamia.png
#       Saved: SW131_Birch_1.png
#       Saved: SW168_Coral_Sands_1.png
#       Saved: SW172_Macadamia_1.png
#       Saved: 5W183_Oxblood.png
#       Saved: 3219_Opal_Lustre.png
#       Saved: W223_Milk_Glass.png
#       Saved: SW183_Oxblood.png
#       Saved: 5W219_Opal_Lustre.png
#       Saved: SW223_Milk_Glass.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
#   Page 2 → cone_10 (12 cells)
#       Saved: EESW131_Birch.png
#       Saved: eeSW168_Coral_Sands.png
#       Saved: eeSW172_Macadamia.png
#       Saved: EEESW131_Birch.png
#       Saved: SW168_Coral_Sands.png
#       Saved: SW172_Macadamia.png
#       Saved: 5W183_Oxblood.png
#       Saved: 5W219_Opal_Lustre.png
#       Saved: W223_Milk_Glass.png
#       Saved: SW183_Oxblood.png
#       Saved: SW219_Opal_Lustre.png
#       Saved: SW223_Milk_Glass.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
# ============================================================
# Processing: SW-223-Milk-Glass.pdf
# ============================================================
#   Page 1 — 1 grid(s) found
#     → 12 cells
#   Page 2 — 1 grid(s) found
#     → 12 cells
#
#   Page 1 → cone_6 (12 cells)
#       Saved: SW105_Frost_Blue.png
#       Saved: SW146_Aurora_Green.png
#       Saved: SW148_Lime_Shower.png
#       Saved: SW105_Frost_Blue_1.png
#       Saved: SW146_Aurora_Green_1.png
#       Saved: SW148_Lime_Shower_1.png
#       Saved: SW172_Macadamia.png
#       Saved: SW173_Amber_Quartz.png
#       Saved: W187_Himalayan_Salt.png
#       Saved: W172_Macadamia.png
#       Saved: SW173_Amber_Quartz_1.png
#       Saved: W187_Himalayan_Salt_1.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
#   Page 2 → cone_10 (12 cells)
#       Saved: SW105_Frost_Blue.png
#       Saved: SW146_Aurora_Green.png
#       Saved: 5W148_Lime_Shower.png
#       Saved: SW105_Frost_Blue_1.png
#       Saved: SW146_Aurora_Green_1.png
#       Saved: SW148_Lime_Shower.png
#       Saved: SW172_Macadamia.png
#       Saved: SW173_Amber_Quartz.png
#       Saved: W187_Himalayan_Salt.png
#       Saved: SW172_Macadamia_1.png
#       Saved: SW173_Amber_Quartz_1.png
#       Saved: W187_Himalayan_Sat.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
# ============================================================
# Processing: SW-224-Tropical-Teal.pdf
# ============================================================
#   Page 1 — 1 grid(s) found
#     → 12 cells
#   Page 2 — 1 grid(s) found
#     → 12 cells
#
#   Page 1 → cone_6 (12 cells)
#       Saved: EEESW169_Frosted_Lemor.png
#       Saved: EW195_Riptide.png
#       Saved: ESW197_Fossil_Rock.png
#       Saved: SW169_Frosted_Lemor.png
#       Saved: W195_Riptide.png
#       Saved: ESW197_Fossil_Rock_1.png
#       Saved: SW214_Micro_Pearl.png
#       Saved: W219_Opal_Lustre.png
#       Saved: W223_Milk_Glass.png
#       Saved: SW214_Micro_Pearl_1.png
#       Saved: 5W219_Opal_Lustre.png
#       Saved: SW223_Milk_Glass.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
#   Page 2 → cone_10 (12 cells)
#       Saved: EeW169_Frosted_Lemor.png
#       Saved: EESW195_Riptide.png
#       Saved: EESW197_Fossil_Rock.png
#       Saved: EESW_169_Frosted_Lemor.png
#       Saved: EEW195_Riptide.png
#       Saved: SW197_Fossil_Rock.png
#       Saved: SW214_Micro_Pearl.png
#       Saved: SW219_Opal_Lustre.png
#       Saved: W223_Milk_Glass.png
#       Saved: SW214_Micro_Pearl_1.png
#       Saved: SW219_Opal_Lustre_1.png
#       Saved: SW223_Milk_Glass.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
# ============================================================
# Processing: SW-514-Sage-Gloss.pdf
# ============================================================
#   Page 1 — 1 grid(s) found
#     → 12 cells
#   Page 2 — 1 grid(s) found
#     → 12 cells
#
#   Page 1 → cone_6 (12 cells)
#       Saved: 5154_Shipwreck.png
#       Saved: W156_Galaxy.png
#       Saved: SW189_Cenote.png
#       Saved: SW154_Shipwreck.png
#       Saved: 53156_Galaxy.png
#       Saved: SW189_Cenote_1.png
#       Saved: SW19T_Peppered_Plun.png
#       Saved: SW192Amaryllis.png
#       Saved: W199_Purple_Aster.png
#       Saved: SW191_Peppered_Plun.png
#       Saved: SW192_Amaryllis.png
#       Saved: SW199_Purple_Aster.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
#   Page 2 → cone_10 (12 cells)
#       Saved: EEESW154_Shipwreck.png
#       Saved: EW156_Galaxy.png
#       Saved: EESW189_Cenote.png
#       Saved: ESW154_Shipwreck.png
#       Saved: EEEW156_Galaxy.png
#       Saved: EEESW189_Cenote.png
#       Saved: SW191_Peppered_Plun.png
#       Saved: SW192Amaryllis.png
#       Saved: W199_Purple_Aster.png
#       Saved: SW-191_Peppered_Plun.png
#       Saved: SW192_Amaryllis.png
#       Saved: W199_Purple_Aster_1.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
# ============================================================
# Processing: SW-515-Aqua-Gloss.pdf
# ============================================================
#   Page 1 — 1 grid(s) found
#     → 12 cells
#   Page 2 — 1 grid(s) found
#     → 12 cells
#
#   Page 1 → cone_6 (12 cells)
#       Saved: S115_Midnight_Rain.png
#       Saved: SW116_Robins_Egg.png
#       Saved: SW117_Honeycomb.png
#       Saved: SW115_Midnight_Rain.png
#       Saved: W116_Robins_Eog.png
#       Saved: SW117_Honeycomb_1.png
#       Saved: SW118_Sea_Salt.png
#       Saved: SW146_Aurora_Green.png
#       Saved: SW155_Winter_Wood.png
#       Saved: SW118_Sea_Salt_1.png
#       Saved: SW146_Aurora_Green_1.png
#       Saved: SW155_Winter_Wood_1.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
#   Page 2 → cone_10 (12 cells)
#       Saved: SW115_Midnight_Rain.png
#       Saved: ESW116_Robins_Egg.png
#       Saved: 7W117_Honeycomb.png
#       Saved: EEESW115_Midnight_Rain.png
#       Saved: EEW116_Robins_Fog.png
#       Saved: EW117_Honeycomb.png
#       Saved: SW118_Sea_Salt.png
#       Saved: SW-146_Aurora_Green.png
#       Saved: SW155_Winter_Wood.png
#       Saved: SW118_Sea_Salt_1.png
#       Saved: SW146_Aurora_Green.png
#       Saved: SW155_Winter_Wood_1.png
#     Swatches detected : 12
#     Files saved       : 12
#     Files in folder   : 12
#
# ============================================================
# All PDFs processed.
