# %% [markdown]
# <a href="https://colab.research.google.com/github/markmilner21/Mayco-Glaze-Similarity-Search/blob/main/rough/data/Manual_document_filter_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In order to process the data, I'll need to manually go through each of these documents to make sure they actually have information on them we can use. In short, if it's not a brochure advertising a specific range of glazes, it probably won't get used.

# %% [markdown]
# # keep list

# %% [markdown]
# 2021 Elements Brochure - 0 - done
#
# 2021 Jungle Gems Brochure - 0 - done
#
# 2021 Stroke & Coat Brochure - 0 - done
#
# -------------------------------
#
# CG1002 Day Lily - 4 - done
#
# CG1003 Peach Party - 4 - done
#
# CG1004 Berry Tart - 4 - done
#
# CG1005 Maroon Lagoon - 4 - done
#
# CG1006 Purple Reign - 4 - done
#
# CG1007 Blueberry Bubblegum
# New!- 4 - done
#
# CG1008 Blue Guppy - 4 - done
#
# CG1009 Cherry Limeade - 4 - done
#
# CG1010 Periwinkle Sky - 4 - done
#
# CG1011 Frosted Berries - 4 - done
#
# CG1012 Haystack - 4 - done
# New!
#
# ---------------------
#
# EL-101 Oyster Shell - 4 - done
#
# EL-103 Sea Spray - 4 - done
#
# EL-106 Tidal Pool - 1
#
# EL-107 Amber Ash - 1
#
# EL-110 Mudslide - 4 - done
#
# EL-113 Spanish Moss - 1
#
# EL-117 Waterfall - 1
#
# EL-118 Blue Grotto - 4 - done
#
# EL-119 Burnished Steel - 1
#
# EL-120 Black Ice - 1
#
# EL-121 Copper Adventurine - 4 - done
#
# EL-122 Malachite - 4 - done
#
# EL-123 Patina - 4 - done
#
# EL-124 Stormy Blue - 4 - done
#
# EL-125 Sahara Sands - 1
#
# EL-127 Rose Granite - 4 - done
#
# EL-128 Wheat - 4 - done
#
# EL-129 Slate - 4 - done
#
# EL-130 Sea Green - 4 - done
#
# EL-131 Turtle Shell - 4 - done
#
# EL-132 Rust Red - 4 - done
#
# EL-133 Autumn - 4 - done
#
# EL-134 Mirror Blue - 4 - done
#
# EL-135 Rare Earth - 4 - done
#
# EL-136 Lapis Lagoon - 4 - done
#
# EL-137 Black Adventurine - 4 -done
#
# EL-152 Denim Blue - 4 -done
#
# EL-153 Caribbean Blue - 4 - done
#
# EL-154 Sea Mist Green - 4 - done
#
# EL-155 Holiday Green - 4 -done
#
# EL143 Cactus Flower - 4 -done
#
# EL145 Ginger Root - 4 -done
#
# EL146 Rain Cloud - 4 - done
#
# EL160 Foliage Green - 4 - done
#
# EL161 Bottle Green - 4 - done
#
# EL211 Volcanic Glow - 4 - done
#
# EL212 Spotted Walnut - 4 - done
#
# ---------------------
#
# Foundations Brochure - 0 - Done
#
# Foundations DE + NL - 0 - done
#
# Fundamentals DE + NL- 0 - not used
#
# Jungle Gems DE + NL - 0 - not used - already have
#
# Stroke & Coat DE + NL - 0 - not used - already have
#
# ----------------------------
#
# Micro Champagne - 1
# NEW!
#
# SW-106 Alabaster - 1 - DONE
#
# SW-108 Green Tea - 3 - DONE
#
# SW-110 Oyster - 1 - DONE
#
# SW-112 Tiger’s Eye - 1 - DONE
#
# SW-113 Speckled Plum - 3 - DONE
#
# SW-115 Midnight Rain - 1 - DONE
#
# SW-117 Honeycomb - 1 - DONE
#
# SW-118 Sea Salt - 3 - DONE
#
# SW-119 Cinnabar - 1 - DONE
#
# SW-125 Purple Mint - 1 - DONE
#
# SW-128 Cordovan - 3 = DONE
#
# SW-129 Copper Float - 1 - DONE
#
# SW-130 Copper Jade - 3 - DONE
#
# SW-131 Birch - 1 - DONE
#
# SW-135 Wintergreen - 1 - Done
#
# SW-143 Abalone - 1 - Done
#
# SW-145 Tea Dust - 3 - DONE
#
# SW-150 Celadon Bloom - 1 - - Done
#
# SW-154 Shipwreck - 3 - DONE
#
# SW-155 Winter Wood - 3 DONE
#
# SW-156 Galaxy - 3 - DONE
#
# SW-166 Norse Blue - 1 - DONE
#
# SW-167 Sand & Sea - 1 - DONE
#
# SW-168 Coral Sands - 3 - DONE
#
# SW-169 Frosted Lemon -3 - DONE
#
# SW-171 Enchanted Forest - 1 - done
#
# SW-172 Macadamia - 1 - DONE
#
# SW-173 Amber Quartz - 1 - done
#
# SW-174 Leather - 1 - done
#
# SW-175 Rusted Iron - 1 - done
#
# SW-176 Sandstone - 3 - DONE
#
# SW-177 Raspberry Mist - 1 - done
#
# SW-178 Fool’s Gold - 1 - done
#
# SW-179 Muddy Waters - 1 - done
#
# SW-180 Desert Dusk - 1 - done
#
# SW-181 Night Moth - 1 - done
#
# SW-184 Speckled Toad - 1 - done
#
# SW-185 Rainforest - ?
#
# SW-186 Azurite - 1 - done
#
# SW-187 Himalayan Salt - 1 - done
#
# SW-188 Landslide - 1 - done
#
# SW-189 Cenote - 1 - done
#
# SW-193 Ivy - 1 - done
#
# SW-194 Nimbus - 1 - done
#
# SW-195 Riptide - 1 - done
#
# SW-196 Sand Dollar - 1 - done
#
# SW-197 Fossil Rock - 1 - done
#
# SW-198 Rose Quartz - 1 - done
#
# SW-203 Root Beer - 1 - done
#
# SW-211 Glacier Blue - 1 - done
#
# SW-251 Pink Opal - 1 - done
#
# SW-252 Blue Opal - 1 - done
#
# SW-253 Green Opal - 1 - done
#
# SW-501-SW-508 Gloss Glazes -
#
# SW-509 Dark Green Gloss - 1 - done
#
# SW-510 Blue Gloss - 1 - done
#
# SW116 Robin’s Egg - 1 - done
#
# SW122 Maycoshino - 1 - done
# New!
#
# SW127 Olivine - 1 - done
#
# SW147 Moonscape - 1 - done
#
# SW201 Turquoise - 1 - done
#
# SW212 Peacock - 1 - done
#
# SW214 Micro Pearl - 1 - done
#
# SW217 Micro Cerulean - 1 - done
#
# SW218 Micro Ash - 1 - done
#
# SW219 Opal Lustre - 1 - done
#
# SW220 Black Timber - 1 - done
#
# SW221 Mint Speck - 1 - done
#
# SW222 Green Jasper - 1 - done
#
# SW223 Milk Glass - 1 - done
#
# SW224 Tropical Teal - 1 - done
#
# SW250 White Opal - 1 - done
#
# SW514 Sage Green - 1 - done
#
# SW515 Aqua Gloss - 1 - done
#
# ------------------------------
#
# Using Mayco Stoneware Glazes – A Comprehensive Guide - 2? - looks like it will need a similar version to 1 but slightly different - DONE

# %% [markdown]
# this data is in various formats
